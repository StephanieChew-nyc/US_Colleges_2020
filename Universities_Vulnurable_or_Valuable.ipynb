# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('US Higher Education Value vs. Vulnerability - dataset.csv')

# %%
test_name = df['Institution Name'] == 'Stony Brook University'
df.loc[test_name]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    object
#  8   Average Monthly Search Volume Pct Rank              438 non-null    float64
#  9   Credential Score                                    438 non-null    float64
#  10  Student Life Grade                                  438 non-null    object
#  11  Student Life Score                                  438 non-null    float64
#  12  Experience Score                                    438 non-null    float64
#  13  15-Year NPV                                         438 non-null    object
#  14  15-Year NPV PCT Rank                                438 non-null    float64
#  15  30-Year NPV                                         438 non-null    object
#  16  30-Year NPV PCT Rank                                438 non-null    float64
#  17  Instructional Wages per Full-Time Student           438 non-null    object
#  18  Instructional Wages per Full-Time Student PCT Rank  438 non-null    float64
#  19  Eduation Score                                      438 non-null    float64
#  20  Average Undergraduate Tuition and Fees              438 non-null    float64
#  21  Average Undergraduate Tuition & Fees Score          438 non-null    float64
#  22  Values                                              438 non-null    float64
#  23  Value-to-Cost Ratio                                 438 non-null    float64
#  24  Endowment per Full Time Student                     438 non-null    int64
#  25  Endowment per Full Time Student Pct Rank            438 non-null    float64
#  26  Percentage of International Students                438 non-null    float64
#  27  Percentage of International Students PCT Rank       438 non-null    float64
#  28  Vulnerability Score                                 438 non-null    float64
#  29  Prof G Categorization                               438 non-null    object
# dtypes: float64(20), int64(2), object(8)
# memory usage: 102.8+ KB

# %%
# df['Value\n(C x E x E)']
#df.rename(columns = {'Value\n(C x E x E)':'Values'}, inplace=True)
#df.drop('Ranking List',axis=1,inplace=True)
#df.melt(id_vars=['Institution Name'], value_vars=['Credential Score'])
#grouped = df.groupby('Prof G Categorization')

#counted_1 = df['Prof G Categorization'].value_counts()


#df['Average Undergraduate Tuition and Fees'] = df['Average Undergraduate Tuition and Fees'].str.strip('$')
#df['Average Undergraduate Tuition and Fees'] = df['Average Undergraduate Tuition and Fees'].str.replace(',','').astype('float')

sns.barplot(x='Percentage of International Students', y='Prof G Categorization', data=df)

# %%
df['Full Time Enrollment'] = df['Full Time Enrollment'].str.replace(',', '').astype('float')

# %%
sns.barplot(x='Prof G Categorization', y='Average Undergraduate Tuition and Fees', data=df)

# %%
#df['Endowment per Full Time Student'] = df['Endowment per Full Time Student'].str.strip('$')

#df['Percentage of International Students'] = df['Percentage of International Students'].str.strip('%').astype("float")*100

# df['Undergraduate Admit Rate'] = df['Undergraduate Admit Rate'].str.strip('%')
# df['Undergraduate Admit Rate'] = df['Undergraduate Admit Rate'].astype('float')/100

df['Average Monthly Search Volume'] = df['Average Monthly Search Volume'].str.replace(',','')



#a[['Undergraduate Admit Rate','Experience Score','Instructional Wages per Full-Time Student','Eduation Score','Average Undergraduate Tuition and Fees','Value','Endowment per Full Time Student','Percentage of International Students','Vulnerability Score']].agg([np.median])
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-248-0d8b33837c7b> in <module>
#       8 df['Average Monthly Search Volume'] = df['Average Monthly Search Volume'].str.replace(',','')
#       9
# ---> 10 sns.lmplot(x='Endowment per Full Time Student', y='Percentage of International Students PCT Rank', data=df)
#      11
#      12 #a[['Undergraduate Admit Rate','Experience Score','Instructional Wages per Full-Time Student','Eduation Score','Average Undergraduate Tuition and Fees','Value','Endowment per Full Time Student','Percentage of International Students','Vulnerability Score']].agg([np.median])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     615         scatter_kws=scatter_kws, line_kws=line_kws,
#     616         )
# --> 617     facets.map_dataframe(regplot, x, y, **regplot_kws)
#     618
#     619     # Add a legend
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     831
#     832             # Draw the plot
# --> 833             self._facet_plot(func, ax, args, kwargs)
#     834
#     835         # Finalize the annotations and layout
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     849
#     850         # Draw the plot
# --> 851         func(*plot_args, **plot_kwargs)
#     852
#     853         # Sort out the supporting information
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     816     scatter_kws["marker"] = marker
#     817     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 818     plotter.plot(ax, scatter_kws, line_kws)
#     819     return ax
#     820
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in plot(self, ax, scatter_kws, line_kws)
#     363
#     364         if self.fit_reg:
# --> 365             self.lineplot(ax, line_kws)
#     366
#     367         # Label the axes
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in lineplot(self, ax, kws)
#     406         """Draw the model."""
#     407         # Fit the regression model
# --> 408         grid, yhat, err_bands = self.fit_regression(ax)
#     409         edges = grid[0], grid[-1]
#     410
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in fit_regression(self, ax, x_range, grid)
#     194                 else:
#     195                     x_min, x_max = ax.get_xlim()
# --> 196             grid = np.linspace(x_min, x_max, 100)
#     197         ci = self.ci
#     198
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     127     # Convert float/complex array scalars to float, gh-3504
#     128     # and make sure one can use variables that have an __array_interface__, gh-6634
# --> 129     start = asanyarray(start) * 1.0
#     130     stop  = asanyarray(stop)  * 1.0
#     131
#
# UFuncTypeError: ufunc 'multiply' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %%
categories = df['Prof G Categorization'] == 'Thrive'

df.loc[categories]
# Out:
#                       Institution Name  Full Time Enrollment State  Rank  \
# 4                  American University               11435.0    DC    77
# 5                      Amherst College                1855.0    MA     2
# 7                    Auburn University               25806.0    AL   104
# 12               Ball State University               15926.0    IN   192
# 25         Birmingham Southern College                1261.0    AL   140
# ..                                 ...                   ...   ...   ...
# 413  Washington University in St Louis               13773.0    MO    19
# 414             Wayne State University               18746.0    MI   246
# 422                Westminster College                2199.0    PA   114
# 432                   Williams College                2096.0    MA     1
# 436                    Yale University               13303.0    CT     3
#
#      Rank Pct Rank  Undergraduate Admit Rate  \
# 4             0.66                      0.32
# 5             1.00                      0.13
# 7             0.55                      0.75
# 12            0.22                      0.65
# 25            0.38                      0.57
# ..             ...                       ...
# 413           0.92                      0.15
# 414           0.10                      0.71
# 422           0.50                      0.66
# 432           1.00                      0.13
# 436           0.99                      0.06
#
#      Undergraduate Admit Rate Pct Rank Average Monthly Search Volume  \
# 4                                 0.84                        110000
# 5                                 0.95                         60500
# 7                                 0.28                        135000
# 12                                0.49                         60500
# 25                                0.65                          8100
# ..                                 ...                           ...
# 413                               0.92                         33100
# 414                               0.37                         74000
# 422                               0.47                         27100
# 432                               0.95                         60500
# 436                               0.99                        165000
#
#      Average Monthly Search Volume Pct Rank  Credential Score  ...  \
# 4                                      0.87              2.37  ...
# 5                                      0.70              2.64  ...
# 7                                      0.90              1.73  ...
# 12                                     0.70              1.41  ...
# 25                                     0.08              1.10  ...
# ..                                      ...               ...  ...
# 413                                    0.47              2.31  ...
# 414                                    0.78              1.25  ...
# 422                                    0.42              1.38  ...
# 432                                    0.70              2.64  ...
# 436                                    0.94              2.92  ...
#
#     Average Undergraduate Tuition and Fees  \
# 4                                  48459.0
# 5                                  56426.0
# 7                                  20900.0
# 12                                 18182.0
# 25                                 17650.0
# ..                                     ...
# 413                                53399.0
# 414                                20544.0
# 422                                36806.0
# 432                                55450.0
# 436                                53430.0
#
#      Average Undergraduate Tuition & Fees Score  Values Value-to-Cost Ratio  \
# 4                                          0.74    9.02                0.45
# 5                                          0.99   21.08                0.79
# 7                                          0.22    5.39                0.92
# 12                                         0.15    2.78                0.67
# 25                                         0.14    1.98                0.52
# ..                                          ...     ...                 ...
# 413                                        0.86   19.56                0.84
# 414                                        0.21    3.62                0.65
# 422                                        0.47    5.43                0.43
# 432                                        0.95   17.22                0.67
# 436                                        0.86   25.75                1.11
#
#      Endowment per Full Time Student Endowment per Full Time Student Pct Rank  \
# 4                             59154                                      0.51
# 5                           1281691                                      0.02
# 7                             29892                                      0.69
# 12                            13453                                      0.87
# 25                            44965                                      0.57
# ..                               ...                                      ...
# 413                          558149                                      0.06
# 414                           21169                                      0.77
# 422                           56121                                      0.52
# 432                         1252990                                      0.02
# 436                         2213406                                      0.00
#
#      Percentage of International Students  \
# 4                                    0.03
# 5                                    0.07
# 7                                    0.01
# 12                                   0.00
# 25                                   0.01
# ..                                    ...
# 413                                  0.08
# 414                                  0.01
# 422                                  0.03
# 432                                  0.09
# 436                                  0.12
#
#     Percentage of International Students PCT Rank  Vulnerability Score  \
# 4                                            0.39                 0.90
# 5                                            0.67                 0.69
# 7                                            0.07                 0.76
# 12                                           0.00                 0.87
# 25                                           0.07                 0.64
# ..                                            ...                  ...
# 413                                          0.71                 0.76
# 414                                          0.07                 0.84
# 422                                          0.39                 0.91
# 432                                          0.74                 0.76
# 436                                          0.83                 0.83
#
#      Prof G Categorization
# 4                   Thrive
# 5                   Thrive
# 7                   Thrive
# 12                  Thrive
# 25                  Thrive
# ..                     ...
# 413                 Thrive
# 414                 Thrive
# 422                 Thrive
# 432                 Thrive
# 436                 Thrive
#
# [93 rows x 30 columns]

# %%
df['Endowment per Full Time Student'] = df['Endowment per Full Time Student'].str.replace(',','')

grouped = df.groupby(['State', 'Prof G Categorization'])
grouped

sns.lmplot(x='Percentage of International Students', y='Vulnerability Score', hue='Prof G Categorization', data=df)

# %%
#sns.lmplot(x='Endowment per Full Time Student', y='Percentage of International Students PCT Rank', data=df)

NY_only = df['State'] == 'NY'

sns.barplot(x='Endowment per Full Time Student', y='Prof G Categorization', data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1302         try:
# -> 1303             x = float(x)
#    1304         except ValueError:
#
# ValueError: could not convert string to float: '28738 66351 34453 69834 131053 44814 18925 33195 198668 27385 45833 148393 31429 44277 178191 63197 76273 41714 7817 359584 341678 185314 48689 42582 399629 30058 38188 17663 53085 168817 94113 19407 35559 7872 32581 65527 42958 6721 240479 122201 61368 239318 20194 27350 42695 84645 360418 16531 11434 68147 354646 3846 12254 340089 154895 17678 18447 134728 9921 68731 33960 62475 146747 653798 52069 124822 275605 152508 8105 107023 28648 162074 42439 20692 23400 293568 17391 11153 5441 15220 34961 23045 19943 8398 13488 7056 12282 22855 79637 52705 19171 112890 95714 '
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1306             try:
# -> 1307                 x = complex(x)
#    1308             except ValueError:
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-299-a1f9c4478007> in <module>
#       3 NY_only = df['State'] == 'NY'
#       4
# ----> 5 sns.barplot(x='Endowment per Full Time Student', y='Prof G Categorization', data=df)
#       6
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1615                                  order, hue_order, units)
#    1616         self.establish_colors(color, palette, saturation)
# -> 1617         self.estimate_statistic(estimator, ci, n_boot, seed)
#    1618
#    1619         self.dodge = dodge
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in estimate_statistic(self, estimator, ci, n_boot, seed)
#    1497                     statistic.append(np.nan)
#    1498                 else:
# -> 1499                     statistic.append(estimator(stat_data))
#    1500
#    1501                 # Get a confidence interval for this estimate
#
# <__array_function__ internals> in mean(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    3330             pass
#    3331         else:
# -> 3332             return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#    3333
#    3334     return _methods._mean(a, axis=axis, dtype=dtype,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11215             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
#   11216         return self._reduce(
# > 11217             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11218         )
#   11219
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     123                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#     127             return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     540         dtype_count = dtype
#     541     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 542     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     543
#     544     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1308             except ValueError:
#    1309                 # e.g. "foo"
# -> 1310                 raise TypeError(f"Could not convert {x} to numeric")
#    1311     return x
#    1312
#
# TypeError: Could not convert 28738 66351 34453 69834 131053 44814 18925 33195 198668 27385 45833 148393 31429 44277 178191 63197 76273 41714 7817 359584 341678 185314 48689 42582 399629 30058 38188 17663 53085 168817 94113 19407 35559 7872 32581 65527 42958 6721 240479 122201 61368 239318 20194 27350 42695 84645 360418 16531 11434 68147 354646 3846 12254 340089 154895 17678 18447 134728 9921 68731 33960 62475 146747 653798 52069 124822 275605 152508 8105 107023 28648 162074 42439 20692 23400 293568 17391 11153 5441 15220 34961 23045 19943 8398 13488 7056 12282 22855 79637 52705 19171 112890 95714  to numeric

# %%
ny_state = df['State'] == 'NY'

##sns.barplot(x='Average Undergraduate Tuition and Fees', y='Vulnerability Score', data=df)
sns.lmplot(x='Percentage of International Students', y='Vulnerability Score', hue='Prof G Categorization', data=df)

# %%
test_name1 = df['Institution Name']=='Cornell University'

df.loc[test_name1]

sns.lmplot(x='Percentage of International Students', 
           y='Undergraduate Admit Rate', hue='Prof G Categorization', height=15, data=df)

plt.savefig("index.png", Transparent=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-324-1b4de7976f9b> in <module>
#       6            y='Undergraduate Admit Rate', hue='Prof G Categorization', height=15, data=df)
#       7
# ----> 8 plt.savefig("index.png", Transparent=True)
#
# NameError: name 'plt' is not defined

# %%
ny_only = df['State'] == 'NY'
pa_only = df['State'] == 'PA'
ca_only = df['State'] == 'CA'
top3= ny_only|pa_only|ca_only

cx = sns.lmplot(x = 'Percentage of International Students', y = 'Vulnerability Score', 
                data = top3, height = 10, hue = 'State', ci = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-313-c288abc580f0> in <module>
#       5
#       6 cx = sns.lmplot(x = 'Percentage of International Students', y = 'Vulnerability Score',
# ----> 7                 data = top3, height = 10, hue = 'State', ci = False)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     577     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     578     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 579     data = data[cols]
#     580
#     581     # Initialize the grid
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     908             key = check_bool_indexer(self.index, key)
#     909
# --> 910         return self._get_with(key)
#     911
#     912     def _get_with(self, key):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in _get_with(self, key)
#     956                 return self._get_values(key)
#     957
# --> 958             return self.loc[key]
#     959
#     960         return self.reindex(key)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1951                     raise ValueError("Cannot index with multidimensional key")
#    1952
# -> 1953                 return self._getitem_iterable(key, axis=axis)
#    1954
#    1955             # nested tuple slicing
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1592         else:
#    1593             # A collection of keys
# -> 1594             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1595             return self.obj._reindex_with_indexers(
#    1596                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Percentage of International Students', 'State', 'Vulnerability Score'], dtype='object')] are in the [index]"

# %%
ax = sns.lmplot(x = 'Endowment per Full Time Student', y = 'Vulnerability Score', data = df, height = 10, hue = 'Prof G Categorization', 
                palette = ["green", "red", "blue", "purple"], markers = ["x", "+", "o","."], ci = False)
